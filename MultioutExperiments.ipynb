# %%
from ADnum_rev_timed_vis import ADnum
import ADmath_rev as ADmath
import ADgraph_GUI as ADgraph

# %matplotlib inline

# %%
x = ADnum(1, ins = 2, ind = 0)
y = ADnum(2, ins=2, ind = 1)
f1 = x+y
f2 = ADmath.sin(x-y)

# %%
dir(ADgraph)
# Out:
# ['ADnum',
#  'Axes3D',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'axis_reverse_edge',
#  'draw_graph',
#  'draw_graph2',
#  'draw_graph_rev',
#  'draw_graph_rev2',
#  'draw_graph_rev_dynamic',
#  'draw_graph_rev_dynamic_old',
#  'gen_graph',
#  'gen_table',
#  'gen_table_rev',
#  'get_colors',
#  'get_graph_setup',
#  'get_labels',
#  'get_labels_rev',
#  'get_sizes',
#  'matplotlib',
#  'mpatches',
#  'np',
#  'nx',
#  'pd',
#  'plot_ADnum',
#  'plt',
#  'reverse_graph']

# %%
ADgraph.gen_table(f1)
# Out:
#   Trace     Operation Value  Derivative
# 1    X0         input   2.0  [0.0, 1.0]
# 2    X1         input   1.0  [1.0, 0.0]
# 0    X2  add(X1 , X0)   3.0  [1.0, 1.0]

# %%
ADgraph.draw_graph_rev(f1)

# %%
ADgraph.draw_graph(f2)

# %%
ADgraph.draw_graph_rev(f1)

# %%
ADgraph.draw_graph_rev(f2)

# %%
x.revder(f1)
# Out:
# (0,
#  [[(<ADnum_rev_timed_vis.ADnum at 0x1c7063350b8>,
#     <ADnum_rev_timed_vis.ADnum at 0x1c706335748>)]])

# %%
y.revder(f2)
# Out:
# (0.0,
#  [[(<ADnum_rev_timed_vis.ADnum at 0x1c7063355f8>,
#     <ADnum_rev_timed_vis.ADnum at 0x1c7063352e8>)],
#   [(<ADnum_rev_timed_vis.ADnum at 0x1c70634f2e8>,
#     <ADnum_rev_timed_vis.ADnum at 0x1c7063355f8>)]])

# %%
def f(x,y): return eval('y-x')

# %%
f(4,1)
# Out:
# -3

# %%
f(3)
# Out:
# 4
