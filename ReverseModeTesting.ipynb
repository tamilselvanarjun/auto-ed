# %%
from ADnum_rev import ADnum
import ADmath_rev as ADmath

# %%
import ADgraph_GUI as ADgraph
# %matplotlib inline

# %%
x = ADnum(2, ins = 2, ind = 0)
y = ADnum(1, ins = 2, ind = 1)

# %%
f = 5*ADmath.log(x**2*y)-3*ADmath.sin(y)+4/ADmath.tanh(x)+3*ADmath.sin(y) #3*y+ADmath.sin(x)

# %%
x.revder(f)
# Out:
# 4.695912680647716

# %%
y.revder(f)
# Out:
# 3.3790930823955807

# %%
f.der
# Out:
# array([4.69591268, 5.        ])

# %%
z = ADnum(3, ins = 2, ind=0)
q = ADnum(2, ins =2, ind=1)

t = z/ADmath.tanh(q)-3*z*q**2

# %%
z.revder(t)
# Out:
# -10.962685279272453

# %%
q.revder(t)
# Out:
# -72.45613097902843

# %%
t.der
# Out:
# array([-10.96268528, -36.22806549])

# %%
ADgraph.draw_graph(f)

# %%
ADgraph.draw_graph(t)

# %%
h = ADnum(3, der = 1)

g = -3*h*h**2+h/(3*h**2)+ADmath.tanh(h)

# %%
h.revder(g)
# Out:
# -81.0271709998716

# %%
g.der
# Out:
# array(-81.027171)

# %%
ADgraph.draw_graph(g)

# %%
r = ADnum(2, der = 1)
s = ADmath.sin(r)+3*r

# %%
ADgraph.draw_graph(s)

# %%
r.revder(s)
# Out:
# 5.167706326905715

# %%
s.der
# Out:
# array(2.58385316)

# %%
s.graph
# Out:
# {<ADnum_rev.ADnum at 0x2082fc78c88>: [(<ADnum_rev.ADnum at 0x2082fc78cf8>,
#    'sin',
#    -0.4161468365471424),
#   (<ADnum_rev.ADnum at 0x2082fc78d68>, 'multiply', array(3.)),
#   (<ADnum_rev.ADnum at 0x2082fc78cf8>, 'sin', -0.4161468365471424),
#   (<ADnum_rev.ADnum at 0x2082fc78d68>, 'multiply', array(3.))],
#  <ADnum_rev.ADnum at 0x2082fc78c50>: [(<ADnum_rev.ADnum at 0x2082fc78d68>,
#    'multiply',
#    array(2.))],
#  <ADnum_rev.ADnum at 0x2082fc78cf8>: [(<ADnum_rev.ADnum at 0x2082fc78da0>,
#    'add',
#    1)],
#  <ADnum_rev.ADnum at 0x2082fc78d68>: [(<ADnum_rev.ADnum at 0x2082fc78da0>,
#    'add',
#    1)]}

# %%
s.graph[r]
# Out:
# [(<ADnum_rev.ADnum at 0x2082fc78cf8>, 'sin', -0.4161468365471424),
#  (<ADnum_rev.ADnum at 0x2082fc78d68>, 'multiply', array(3.)),
#  (<ADnum_rev.ADnum at 0x2082fc78cf8>, 'sin', -0.4161468365471424),
#  (<ADnum_rev.ADnum at 0x2082fc78d68>, 'multiply', array(3.))]

# %%
w = ADnum(-1, der = 1)
b = w/2+w**2

ADgraph.draw_graph(b)

# %%
w.revder(b)
# Out:
# -1.5

# %%
b.der
# Out:
# array(-1.5)

# %%
b.graph
# Out:
# {<ADnum_rev.ADnum at 0x20831d77630>: [(<ADnum_rev.ADnum at 0x20831d77320>,
#    'divide',
#    0.5),
#   (<ADnum_rev.ADnum at 0x20831d770b8>, 'pow', -2.0)],
#  <ADnum_rev.ADnum at 0x20831d77278>: [(<ADnum_rev.ADnum at 0x20831d77320>,
#    'divide',
#    0.25)],
#  <ADnum_rev.ADnum at 0x20831d77128>: [(<ADnum_rev.ADnum at 0x20831d770b8>,
#    'pow',
#    0.0)],
#  <ADnum_rev.ADnum at 0x20831d77320>: [(<ADnum_rev.ADnum at 0x20831d77dd8>,
#    'add',
#    1)],
#  <ADnum_rev.ADnum at 0x20831d770b8>: [(<ADnum_rev.ADnum at 0x20831d77dd8>,
#    'add',
#    1)]}

# %%
m = ADnum(0, der = 1)
n = 2+3+m
ADgraph.draw_graph(n)
